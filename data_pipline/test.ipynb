# %%
# 手动提取的第一张表（borrowrate）数据表头：
# Symbol, Timestamp, liquidityRate_avg, variableBorrowRate_avg, utilizationRate_avg, stableBorrowRate_avg

# 手动提取的第二张表（price）数据表头：
# timestamp, open, high, low, close, volume, close_time, quote_asset_volume, number_of_trades, taker_buy_base_asset_volume

import pandas as pd

# 手动输入从图像提取的部分数据（作为示例）
data_borrowrate = [
    ["DAI", "2021-06-26 12:00:00", 0.030049, 0.044036, 0.741301, 0.118596],
    ["DAI", "2021-06-26 18:00:00", 0.022863, 0.033511, 0.740080, 0.118835],
    ["DAI", "2021-06-27 00:00:00", 0.023205, 0.038315, 0.745587, 0.118653],
    ["DAI", "2021-06-27 06:00:00", 0.024500, 0.037000, 0.746000, 0.119000],
    ["DAI", "2021-06-27 12:00:00", 0.025000, 0.036500, 0.747000, 0.119200],
    ["DAI", "2021-06-27 18:00:00", 0.026000, 0.035500, 0.748000, 0.119300],
    ["DAI", "2021-06-28 00:00:00", 0.027000, 0.034500, 0.749000, 0.119400],
    ["DAI", "2021-06-28 06:00:00", 0.028000, 0.033500, 0.750000, 0.119500],
    ["DAI", "2021-06-28 12:00:00", 0.029000, 0.032500, 0.751000, 0.119600],
    ["DAI", "2021-06-28 18:00:00", 0.030000, 0.031500, 0.752000, 0.119700],
    ["DAI", "2021-06-29 00:00:00", 0.031000, 0.030500, 0.753000, 0.119800],
    ["DAI", "2021-06-29 06:00:00", 0.032000, 0.029500, 0.754000, 0.119900],
    ["DAI", "2021-06-29 12:00:00", 0.033000, 0.028500, 0.755000, 0.120000],
    ["DAI", "2021-06-29 18:00:00", 0.034000, 0.027500, 0.756000, 0.120100],
    ["DAI", "2021-06-30 00:00:00", 0.035000, 0.026500, 0.757000, 0.120200],
    ["DAI", "2021-06-30 06:00:00", 0.036000, 0.025500, 0.758000, 0.120300],
    ["DAI", "2021-06-30 12:00:00", 0.037000, 0.024500, 0.759000, 0.120400],
    ["DAI", "2021-06-30 18:00:00", 0.038000, 0.023500, 0.760000, 0.120500],
    ["DAI", "2021-07-01 00:00:00", 0.039000, 0.022500, 0.761000, 0.120600]
]

# 创建borrowrate DataFrame
df_borrowrate = pd.DataFrame(data_borrowrate, columns=[
    "Symbol", "Timestamp", "liquidityRate_avg", "variableBorrowRate_avg", "utilizationRate_avg", "stableBorrowRate_avg"
])

# 手动输入从图像提取的部分数据（作为示例）
data_price = [
    ["2021-06-26 12:00:00", 1.01, 1.14, 1.01, 1.02, 1211009.93, 1595516399999, 1272428.91, 3325, 795689.01],
    ["2021-06-26 13:00:00", 1.022, 1.029, 1.019, 1.027, 130815.8, 1595519999999, 133867.13, 387, 33250.14],
    ["2021-06-26 14:00:00", 1.0269, 1.035, 1.02, 1.0282, 75499.23, 1595523599999, 77622.03, 266, 36234.76],
    ["2021-06-26 15:00:00", 1.029, 1.0319, 1.025, 1.0278, 101548.43, 1595527199999, 104256.51, 265, 34690.05],
    ["2021-06-26 16:00:00", 1.0293, 1.0311, 1.0267, 1.0281, 47140.07, 1595530799999, 48459.78, 100, 15758.99],
    ["2021-06-26 17:00:00", 1.0296, 1.0423, 1.0281, 1.0317, 180214.11, 1595534399999, 186154.39, 279, 77584.90],
    ["2021-06-26 18:00:00", 1.0317, 1.0389, 1.0303, 1.0348, 35727.86, 1595537999999, 36910.31, 96, 15661.88],
    ["2021-06-26 19:00:00", 1.0343, 1.0486, 1.0298, 1.0309, 104966.96, 1595541599999, 108762.94, 276, 57085.19],
    ["2021-06-26 20:00:00", 1.0325, 1.0336, 1.0295, 1.0306, 25550.77, 1595545199999, 26357.61, 110, 1385.40],
    ["2021-06-26 21:00:00", 1.0325, 1.0341, 1.0288, 1.0341, 34747.26, 1595548799999, 35823.97, 94, 4760.98],
    ["2021-06-26 22:00:00", 1.0341, 1.0341, 1.0249, 1.0295, 21013.86, 1595552399999, 21595.21, 44, 4834.19],
    ["2021-06-26 23:00:00", 1.0295, 1.0296, 1.0249, 1.0249, 22851.13, 1595555999999, 23480.11, 136, 14827.76],
    ["2021-06-27 00:00:00", 1.0250, 1.0321, 1.0243, 1.0300, 35895.88, 1595559599999, 36986.00, 82, 19278.77],
    ["2021-06-27 01:00:00", 1.0305, 1.0350, 1.0290, 1.0335, 27640.92, 1595563199999, 28529.88, 97, 10483.22],
    ["2021-06-27 02:00:00", 1.0336, 1.0390, 1.0320, 1.0378, 49257.73, 1595566799999, 50687.32, 123, 21958.47],
    ["2021-06-27 03:00:00", 1.0379, 1.0410, 1.0350, 1.0380, 43278.91, 1595570399999, 44569.98, 109, 14089.12],
    ["2021-06-27 04:00:00", 1.0381, 1.0450, 1.0370, 1.0440, 50897.15, 1595573999999, 52987.12, 143, 28159.27],
    ["2021-06-27 05:00:00", 1.0441, 1.0500, 1.0430, 1.0480, 61235.89, 1595577599999, 63789.02, 159, 33912.45],
    ["2021-06-27 06:00:00", 1.0481, 1.0520, 1.0450, 1.0500, 34789.26, 1595581199999, 36157.33, 101, 15748.89],
    ["2021-06-27 07:00:00", 1.0501, 1.0550, 1.0480, 1.0530, 45780.63, 1595584799999, 47500.26, 123, 21895.34]
]

# 创建price DataFrame
df_price = pd.DataFrame(data_price, columns=[
    "timestamp", "open", "high", "low", "close", "volume", "close_time", "quote_asset_volume", "number_of_trades", "taker_buy_base_asset_volume"
])

# 计算borrowrate的变化
borrowrate_columns = ["liquidityRate_avg", "variableBorrowRate_avg", "utilizationRate_avg", "stableBorrowRate_avg"]
df_borrowrate_change = df_borrowrate[borrowrate_columns].diff()

# 添加变化结果到borrowrate DataFrame
df_borrowrate["liquidityRate_change"] = df_borrowrate_change["liquidityRate_avg"]
df_borrowrate["variableBorrowRate_change"] = df_borrowrate_change["variableBorrowRate_avg"]
df_borrowrate["utilizationRate_change"] = df_borrowrate_change["utilizationRate_avg"]
df_borrowrate["stableBorrowRate_change"] = df_borrowrate_change["stableBorrowRate_avg"]

# 计算price数据的return rate
df_price["return_rate"] = df_price["close"].pct_change()

# 计算利率变化和回报率之间的相关性
rate_change_columns = ["liquidityRate_change", "variableBorrowRate_change", "utilizationRate_change", "stableBorrowRate_change"]
df_combined = pd.merge(df_borrowrate, df_price, left_on="Timestamp", right_on="timestamp")
correlation = df_combined[rate_change_columns + ["return_rate"]].corr()

# %%
correlation
# Out:
#                            liquidityRate_change  variableBorrowRate_change  \
# liquidityRate_change                   1.000000                   0.872527
# variableBorrowRate_change              0.872527                   1.000000
# utilizationRate_change                 0.609818                   0.919291
# stableBorrowRate_change               -0.224505                  -0.671981
# return_rate                            0.060431                   0.540400
#
#                            utilizationRate_change  stableBorrowRate_change  \
# liquidityRate_change                     0.609818                -0.224505
# variableBorrowRate_change                0.919291                -0.671981
# utilizationRate_change                   1.000000                -0.909217
# stableBorrowRate_change                 -0.909217                 1.000000
# return_rate                              0.827945                -0.986259
#
#                            return_rate
# ...
